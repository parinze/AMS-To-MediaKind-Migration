# %%
subscription_dev = "dolphmediasvc301_dev"
subscription_qa = "dolphmediasvc101_qa"
subscription_stage = "dolphmediasvc201_stage"

dev_params = [subscription_dev, "generated_migration_files/DEV_streaming_locators.txt"]
qa_params = [subscription_qa, "generated_migration_files/QA_streaming_locators.txt"]
stage_params = [subscription_stage, "generated_migration_files/STAGE_streaming_locators.txt"]

# %%
for x in (dev_params, qa_params, stage_params):
    print(x[0])
# Out:
# dolphmediasvc301_dev
# dolphmediasvc101_qa
# dolphmediasvc201_stage

# %% [markdown]
# # List Streaming Locators

# %%
import requests
import os

selectedParams = qa_params
subscriptionName = selectedParams[0]

url = f"https://api.mk.io/api/ams/{subscriptionName}/streamingLocators"

headers = {
    "accept": "application/json",
    "x-mkio-token": os.environ["MKIO_TOKEN"]
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {
#   "value": [
#     {
#       "name": "locator-03120de786554938b38d692a4f9eaf12",
#       "id": "/subscriptions/57bf8c9c-9aab-4025-bc13-18bfa85a2c78/resourceGroups/default/providers/Microsoft.Media/mediaservices/dolphmediasvc101_qa/streamingLocators/locator-03120de786554938b38d692a4f9eaf12",
#       "type": "Microsoft.Media/mediaservices/streamingLocators",
#       "supplemental": {
#         "etag": "906013de48fd45311ec1b3793be0d836"
#       },
#       "properties": {
#         "assetName": "output-03120de786554938b38d692a4f9eaf12",
#         "created": "2024-06-28T02:25:40.693551Z",
#         "streamingLocatorId": "2a3a793f-b130-4b3c-a695-502de9ae0697",
#         "streamingPolicyName": "Predefined_MultiDrmCencStreaming",
#         "contentKeys": [
#           {
#             "id": "d5991dd3-c38a-bf22-9514-01807d007360",
#             "type": "CommonEncryptionCenc",
#             "tracks": [],
#             "labelReferenceInStreamingPolicy": "cencDefaultKey"
#           }
# ...

# %%
import requests

url = "https://api.mk.io/api/ams/dolphmediasvc101_qa/contentKeyPolicies/DRMContentKeyPolicy"

headers = {
    "accept": "application/json",
    "x-mkio-token": "eyJhbGciOiJSUzI1NiIsImtpZCI6IjFjYTA4ZjdhOTFmYzQ3NGE5YzkzZDE1MDYwZjQ4NDc1IiwidHlwIjoiSldUIn0..vS_gVw6uzrZ0sqd62evush1nXsyfn8XFb4xUL0LVAhWOI_naaW-vvUnP6YClnRRVU7C4kl-lQrla9pFEiGG5NwuBzz_AqTDTJcVAmuqt4l18oULKMJyQpORwnJW1beW2qRtFVGsKhQM-GTxS928WiLyvlFvy1Y3fIIa0Jlj-Q9RFHE3hrhXrjbvRelwZOgj_N2PE6pN4Ye7OXNZxIn-qVsQfgh2RRBKT3eJ0VZmHsJCi2GJvMv9ZEo7ZuE3GRPYcjsKj9DkefgMeZWN-6pnYouXx6IsZP5isd9fKIx3ze-aTiaJREjQIoc1oZfnPPkdr2ceLCAMn0l6fk3u6GIuPvA"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {
#   "name": "DRMContentKeyPolicy",
#   "id": "/subscriptions/57bf8c9c-9aab-4025-bc13-18bfa85a2c78/resourceGroups/default/providers/Microsoft.Media/mediaservices/dolphmediasvc101_qa/contentKeyPolicies/DRMContentKeyPolicy",
#   "type": "Microsoft.Media/mediaservices/contentKeyPolicies",
#   "supplemental": {
#     "id": "7ed483ae-105a-4af9-bc8d-ec8b8e214542",
#     "state": "Created"
#   },
#   "properties": {
#     "options": [
#       {
#         "name": "Widevine",
#         "restriction": {
#           "issuer": "https://test-platform-token-api.practicemgmt-test.pattersondevops.com/sts",
#           "audience": "AqDrmAudience",
#           "@odata.type": "#Microsoft.Media.ContentKeyPolicyTokenRestriction",
#           "restrictionTokenType": "Jwt",
#           "primaryVerificationKey": {
#             "keyValue": "",
#             "@odata.type": "#Microsoft.Media.ContentKeyPolicySymmetricTokenKey"
#           }
#         },
#         "configuration": {
# ...
